# %%
import cv2
import numpy as np

# %%
img_input = cv2.imread("map_1764687152.pgm")
cv2.imwrite("map_practice.jpg", img_input)
# Out:
# True

# %%
img_input = cv2.imread("map_1764936172.pgm")
cv2.imwrite("map_compete.png", img_input)
# Out:
# True
